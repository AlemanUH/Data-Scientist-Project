# %%
import json
import os
directorio = input("ponga el directorio donde se hará la búsqueda")
with os.scandir(directorio) as carpetas :
    for carpeta in carpetas :
        #print (carpeta)
        directorio1 = directorio + "\\" + str(carpeta.name)
        print (directorio1)
        with os.scandir(directorio1) as archivos :
            for archivo in archivos : 
                with open(archivo, "r") as file:
                    data = json.load(file)
                    print (data)
# Out:
# C:\JUEGOS\Phyton works\PROYECTO DE AÑO CIENCIA DE DATOS\Playa\Arroyo Naranjo
# ...

# %%
# Out:
# HolaMundo
